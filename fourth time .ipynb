# %%
import os
import cv2
import numpy as np
import mediapipe as mp

# %%
cap=cv2.VideoCapture(0)
directory='Image/'
while True:
    _,frame=cap.read()
    count = {
             'a': len(os.listdir(directory+"/A")),
             'b': len(os.listdir(directory+"/B")),
             'c': len(os.listdir(directory+"/C")),
             'd': len(os.listdir(directory+"/D")),
             'e': len(os.listdir(directory+"/E")),
             'f': len(os.listdir(directory+"/F")),
             'g': len(os.listdir(directory+"/G")),
             'h': len(os.listdir(directory+"/H")),
             'i': len(os.listdir(directory+"/I")),
             'j': len(os.listdir(directory+"/J")),
             'k': len(os.listdir(directory+"/K")),
             'l': len(os.listdir(directory+"/L")),
             'm': len(os.listdir(directory+"/M")),
             'n': len(os.listdir(directory+"/N")),
             'o': len(os.listdir(directory+"/O")),
             'p': len(os.listdir(directory+"/P")),
             'q': len(os.listdir(directory+"/Q")),
             'r': len(os.listdir(directory+"/R")),
             's': len(os.listdir(directory+"/S")),
             't': len(os.listdir(directory+"/T")),
             'u': len(os.listdir(directory+"/U")),
             'v': len(os.listdir(directory+"/V")),
             'w': len(os.listdir(directory+"/W")),
             'x': len(os.listdir(directory+"/X")),
             'y': len(os.listdir(directory+"/Y")),
             'z': len(os.listdir(directory+"/Z"))
             }
    row = frame.shape[1]
    col = frame.shape[0]
    cv2.rectangle(frame,(0,40),(300,400),(255,255,255),2)
    cv2.imshow("data",frame)
    cv2.imshow("ROI",frame[40:400,0:300])
    frame=frame[40:400,0:300]
    interrupt = cv2.waitKey(10)
    if interrupt & 0xFF == ord('a'):
        cv2.imwrite(directory+'A/'+str(count['a'])+'.png',frame)
    if interrupt & 0xFF == ord('b'):
        cv2.imwrite(directory+'B/'+str(count['b'])+'.png',frame)
    if interrupt & 0xFF == ord('c'):
        cv2.imwrite(directory+'C/'+str(count['c'])+'.png',frame)
    if interrupt & 0xFF == ord('d'):
        cv2.imwrite(directory+'D/'+str(count['d'])+'.png',frame)
    if interrupt & 0xFF == ord('e'):
        cv2.imwrite(directory+'E/'+str(count['e'])+'.png',frame)
    if interrupt & 0xFF == ord('f'):
        cv2.imwrite(directory+'F/'+str(count['f'])+'.png',frame)
    if interrupt & 0xFF == ord('g'):
        cv2.imwrite(directory+'G/'+str(count['g'])+'.png',frame)
    if interrupt & 0xFF == ord('h'):
        cv2.imwrite(directory+'H/'+str(count['h'])+'.png',frame)
    if interrupt & 0xFF == ord('i'):
        cv2.imwrite(directory+'I/'+str(count['i'])+'.png',frame)
    if interrupt & 0xFF == ord('j'):
        cv2.imwrite(directory+'J/'+str(count['j'])+'.png',frame)
    if interrupt & 0xFF == ord('k'):
        cv2.imwrite(directory+'K/'+str(count['k'])+'.png',frame)
    if interrupt & 0xFF == ord('l'):
        cv2.imwrite(directory+'L/'+str(count['l'])+'.png',frame)
    if interrupt & 0xFF == ord('m'):
        cv2.imwrite(directory+'M/'+str(count['m'])+'.png',frame)
    if interrupt & 0xFF == ord('n'):
        cv2.imwrite(directory+'N/'+str(count['n'])+'.png',frame)
    if interrupt & 0xFF == ord('o'):
        cv2.imwrite(directory+'O/'+str(count['o'])+'.png',frame)
    if interrupt & 0xFF == ord('p'):
        cv2.imwrite(directory+'P/'+str(count['p'])+'.png',frame)
    if interrupt & 0xFF == ord('q'):
        cv2.imwrite(directory+'Q/'+str(count['q'])+'.png',frame)
    if interrupt & 0xFF == ord('r'):
        cv2.imwrite(directory+'R/'+str(count['r'])+'.png',frame)
    if interrupt & 0xFF == ord('s'):
        cv2.imwrite(directory+'S/'+str(count['s'])+'.png',frame)
    if interrupt & 0xFF == ord('t'):
        cv2.imwrite(directory+'T/'+str(count['t'])+'.png',frame)
    if interrupt & 0xFF == ord('u'):
        cv2.imwrite(directory+'U/'+str(count['u'])+'.png',frame)
    if interrupt & 0xFF == ord('v'):
        cv2.imwrite(directory+'V/'+str(count['v'])+'.png',frame)
    if interrupt & 0xFF == ord('w'):
        cv2.imwrite(directory+'W/'+str(count['w'])+'.png',frame)
    if interrupt & 0xFF == ord('x'):
        cv2.imwrite(directory+'X/'+str(count['x'])+'.png',frame)
    if interrupt & 0xFF == ord('y'):
        cv2.imwrite(directory+'Y/'+str(count['y'])+'.png',frame)
    if interrupt & 0xFF == ord('z'):
        cv2.imwrite(directory+'Z/'+str(count['z'])+'.png',frame)


cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14516\1940359354.py in <module>
#      37     cv2.imshow("ROI",frame[40:400,0:300])
#      38     frame=frame[40:400,0:300]
# ---> 39     interrupt = cv2.waitKey(10)
#      40     if interrupt & 0xFF == ord('a'):
#      41         cv2.imwrite(directory+'A/'+str(count['a'])+'.png',frame)
#
# KeyboardInterrupt:

# %%
cv2.rectangle??

# %%
cap.release()
cv2.destroyAllWindows()

# %%
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_hands = mp.solutions.hands

# %%
def mediapipe_detection(image,model):
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    image.flags.writeable = False 
    results = model.process(image)
    image.flags.writeable = True 
    image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
    return image,results

# %%
def draw_styled_landmarks(image, results):
    if results.multi_hand_landmarks:
      for hand_landmarks in results.multi_hand_landmarks:
        mp_drawing.draw_landmarks(
            image,
            hand_landmarks,
            mp_hands.HAND_CONNECTIONS,
            mp_drawing_styles.get_default_hand_landmarks_style(),
            mp_drawing_styles.get_default_hand_connections_style())

# %%
def extract_keypoints(results):
    if results.multi_hand_landmarks:
      for hand_landmarks in results.multi_hand_landmarks:
        rh = np.array([[res.x, res.y, res.z] for res in hand_landmarks.landmark]).flatten() if hand_landmarks else np.zeros(21*3)
        return(np.concatenate([rh]))

# %%
DATA_PATH = os.path.join('MP_Data')

# %%
actions = np.array(['A','B','C'])

no_sequences = 15

sequence_length = 15

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
with mp_hands.Hands(
    model_complexity=0,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as hands:
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                # ret, frame = cap.read()
                frame=cv2.imread('Image/{}/{}.png'.format(action,sequence))
                # frame=cv2.imread('{}{}.png'.format(action,sequence))
                # frame=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

                # Make detections
                image, results = mediapipe_detection(frame, hands)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0:
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(200)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    # cap.release()
    cv2.destroyAllWindows()

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.12.0-cp310-cp310-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Downloading tensorflow_intel-2.12.0-cp310-cp310-win_amd64.whl (272.8 MB)
#      ------------------------------------ 272.8/272.8 MB 799.9 kB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 1.2 MB/s eta 0:00:00
# Collecting jax>=0.3.15
#   Downloading jax-0.4.8.tar.gz (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 596.2 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ------------------------------------ 440.7/440.7 kB 377.6 kB/s eta 0:00:00
# Collecting keras<2.13,>=2.12.0
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\tript\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\tript\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.54.0-cp310-cp310-win_amd64.whl (4.1 MB)
#      ---------------------------------------- 4.1/4.1 MB 1.6 MB/s eta 0:00:00
# Collecting tensorboard<2.13,>=2.12
#   Downloading tensorboard-2.12.2-py3-none-any.whl (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 2.0 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.0-py2.py3-none-win_amd64.whl (24.4 MB)
#      ---------------------------------------- 24.4/24.4 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\tript\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (22.0)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.5/57.5 kB 1.5 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ---------------------------------------- 65.5/65.5 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\tript\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\tript\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\tript\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.3.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\tript\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\tript\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.20.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\tript\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\tript\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\tript\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.7 in c:\users\tript\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.0)
# Collecting ml-dtypes>=0.0.3
#   Downloading ml_dtypes-0.1.0-cp310-cp310-win_amd64.whl (120 kB)
#      -------------------------------------- 120.4/120.4 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: markdown>=2.6.8 in c:\users\tript\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\tript\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ------------------------------------ 781.3/781.3 kB 795.8 kB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\tript\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.2)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.17.3-py2.py3-none-any.whl (178 kB)
#      ------------------------------------ 178.2/178.2 kB 671.8 kB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-any.whl (2.4 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tript\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\tript\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tript\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tript\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tript\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\tript\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tript\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 1.3 MB/s eta 0:00:00
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml): started
#   Building wheel for jax (pyproject.toml): finished with status 'done'
#   Created wheel for jax: filename=jax-0.4.8-py3-none-any.whl size=1439795 sha256=981df1f8b40c68a4b34495e8dec6c8170ef6ac43e123f677a1a0eb10ef818cae
#   Stored in directory: c:\users\tript\appdata\local\pip\cache\wheels\d6\f6\d5\63686989c723075de411cbc630ca12f4241a8436e411e38d6a
# Successfully built jax
# Installing collected packages: tensorboard-plugin-wit, libclang, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, opt-einsum, oauthlib, ml-dtypes, keras, grpcio, google-pasta, gast, cachetools, astunparse, requests-oauthlib, jax, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed astunparse-1.6.3 cachetools-5.3.0 gast-0.4.0 google-auth-2.17.3 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.54.0 jax-0.4.8 keras-2.12.0 libclang-16.0.0 ml-dtypes-0.1.0 oauthlib-3.2.2 opt-einsum-3.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.12.2 tensorboard-data-server-0.7.0 tensorboard-plugin-wit-1.8.1 tensorflow-2.12.0 tensorflow-estimator-2.12.0 tensorflow-intel-2.12.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.callbacks import TensorBoard

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'A': 0, 'B': 1, 'C': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(15,63)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=200, callbacks=[tb_callback])
# Out:
# Epoch 1/200
# 2/2 [==============================] - 0s 28ms/step - loss: 1.4192e-08 - categorical_accuracy: 1.0000
# Epoch 2/200
# 2/2 [==============================] - 0s 35ms/step - loss: 1.4192e-08 - categorical_accuracy: 1.0000
# Epoch 3/200
# 2/2 [==============================] - 0s 38ms/step - loss: 1.4192e-08 - categorical_accuracy: 1.0000
# Epoch 4/200
# 2/2 [==============================] - 0s 34ms/step - loss: 1.4192e-08 - categorical_accuracy: 1.0000
# Epoch 5/200
# 2/2 [==============================] - 0s 36ms/step - loss: 1.4192e-08 - categorical_accuracy: 1.0000
# Epoch 6/200
# 2/2 [==============================] - 0s 34ms/step - loss: 1.4192e-08 - categorical_accuracy: 1.0000
# Epoch 7/200
# 2/2 [==============================] - 0s 52ms/step - loss: 1.4192e-08 - categorical_accuracy: 1.0000
# Epoch 8/200
# 2/2 [==============================] - 0s 40ms/step - loss: 1.4192e-08 - categorical_accuracy: 1.0000
# Epoch 9/200
# 2/2 [==============================] - 0s 31ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 10/200
# 2/2 [==============================] - 0s 29ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 11/200
# 2/2 [==============================] - 0s 33ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 12/200
# 2/2 [==============================] - 0s 34ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 13/200
# 2/2 [==============================] - 0s 31ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 14/200
# 2/2 [==============================] - 0s 59ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 15/200
# 2/2 [==============================] - 0s 48ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 16/200
# 2/2 [==============================] - 0s 34ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 17/200
# 2/2 [==============================] - 0s 121ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 18/200
# 2/2 [==============================] - 0s 51ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 19/200
# 2/2 [==============================] - 0s 37ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 20/200
# 2/2 [==============================] - 0s 30ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 21/200
# 2/2 [==============================] - 0s 54ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 22/200
# 2/2 [==============================] - 0s 47ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 23/200
# 2/2 [==============================] - 0s 30ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 24/200
# 2/2 [==============================] - 0s 32ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 25/200
# 2/2 [==============================] - 0s 31ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 26/200
# 2/2 [==============================] - 0s 35ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 27/200
# 2/2 [==============================] - 0s 29ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 28/200
# 2/2 [==============================] - 0s 27ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 29/200
# 2/2 [==============================] - 0s 35ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 30/200
# 2/2 [==============================] - 0s 19ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 31/200
# 2/2 [==============================] - 0s 24ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 32/200
# 2/2 [==============================] - 0s 20ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 33/200
# 2/2 [==============================] - 0s 25ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 34/200
# 2/2 [==============================] - 0s 20ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 35/200
# 2/2 [==============================] - 0s 31ms/step - loss: 1.1353e-08 - categorical_accuracy: 1.0000
# Epoch 36/200
# 2/2 [==============================] - 0s 58ms/step - loss: 8.5149e-09 - categorical_accuracy: 1.0000
# Epoch 37/200
# 2/2 [==============================] - 0s 22ms/step - loss: 8.5149e-09 - categorical_accuracy: 1.0000
# Epoch 38/200
# 2/2 [==============================] - 0s 188ms/step - loss: 8.5149e-09 - categorical_accuracy: 1.0000
# Epoch 39/200
# 2/2 [==============================] - 0s 60ms/step - loss: 8.5149e-09 - categorical_accuracy: 1.0000
# Epoch 40/200
# 2/2 [==============================] - 0s 26ms/step - loss: 8.5149e-09 - categorical_accuracy: 1.0000
# Epoch 41/200
# 2/2 [==============================] - 0s 31ms/step - loss: 8.5149e-09 - categorical_accuracy: 1.0000
# Epoch 42/200
# 2/2 [==============================] - 0s 29ms/step - loss: 8.5149e-09 - categorical_accuracy: 1.0000
# Epoch
ms/step - loss: 5.6766e-09 - categorical_accuracy: 1.0000
# Epoch 193/200
# 2/2 [==============================] - 0s 30ms/step - loss: 5.6766e-09 - categorical_accuracy: 1.0000
# Epoch 194/200
# 2/2 [==============================] - 0s 31ms/step - loss: 5.6766e-09 - categorical_accuracy: 1.0000
# Epoch 195/200
# 2/2 [==============================] - 0s 30ms/step - loss: 5.6766e-09 - categorical_accuracy: 1.0000
# Epoch 196/200
# 2/2 [==============================] - 0s 66ms/step - loss: 5.6766e-09 - categorical_accuracy: 1.0000
# Epoch 197/200
# 2/2 [==============================] - 0s 30ms/step - loss: 5.6766e-09 - categorical_accuracy: 1.0000
# Epoch 198/200
# 2/2 [==============================] - 0s 17ms/step - loss: 5.6766e-09 - categorical_accuracy: 1.0000
# Epoch 199/200
# 2/2 [==============================] - 0s 32ms/step - loss: 5.6766e-09 - categorical_accuracy: 1.0000
# Epoch 200/200
# 2/2 [==============================] - 0s 30ms/step - loss: 5.6766e-09 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 15, 64)            32768
#
#  lstm_1 (LSTM)               (None, 15, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 26)                858
#
# =================================================================
# Total params: 188,090
# Trainable params: 188,090
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save('model.h5')

# %%
colors = []
for i in range(0,20):
    colors.append((245,117,16))
print(len(colors))
# Out:
# 20

# %%
def prob_viz(res, actions, input_frame, colors,threshold):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
accuracy=[]
predictions = []
threshold = 0.8 

cap = cv2.VideoCapture(0)
# cap = cv2.VideoCapture("https://192.168.43.41:8080/video")
# Set mediapipe model 
with mp_hands.Hands(
    model_complexity=0,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as hands:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        cropframe=frame[40:400,0:300]
        # print(frame.shape)
        frame=cv2.rectangle(frame,(0,40),(300,400),255,2)
        # frame=cv2.putText(frame,"Active Region",(75,25),cv2.FONT_HERSHEY_COMPLEX_SMALL,2,255,2)
        image, results = mediapipe_detection(cropframe, hands)
        # print(results)
        
        # Draw landmarks
        # draw_styled_landmarks(image, results)
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-15:]

        try: 
            if len(sequence) == 15:
                res = model.predict(np.expand_dims(sequence, axis=0))[0]
                print(actions[np.argmax(res)])
                predictions.append(np.argmax(res))
                
                
            #3. Viz logic
                if np.unique(predictions[-10:])[0]==np.argmax(res): 
                    if res[np.argmax(res)] > threshold: 
                        if len(sentence) > 0: 
                            if actions[np.argmax(res)] != sentence[-1]:
                                sentence.append(actions[np.argmax(res)])
                                accuracy.append(str(res[np.argmax(res)]*100))
                        else:
                            sentence.append(actions[np.argmax(res)])
                            accuracy.append(str(res[np.argmax(res)]*100)) 

                if len(sentence) > 1: 
                    sentence = sentence[-1:]
                    accuracy=accuracy[-1:]

                # Viz probabilities
                # frame = prob_viz(res, actions, frame, colors,threshold)
        except Exception as e:
            # print(e)
            pass
        cv2.rectangle(frame, (0,0), (300, 40), (245, 117, 16), -1)
        cv2.putText(frame,"Output: -"+' '.join(sentence)+''.join(accuracy), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', frame)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# C:\Users\tript\anaconda3\lib\site-packages\numpy\lib\shape_base.py:591: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   a = asanyarray(a)
# 1/1 [==============================] - 1s 551ms/step
# V
# 1/1 [==============================] - 0s 70ms/step
# H
# 1/1 [==============================] - 0s 34ms/step
# H
# 1/1 [==============================] - 0s 43ms/step
# H
# 1/1 [==============================] - 0s 51ms/step
# H
# 1/1 [==============================] - 0s 28ms/step
# H
# 1/1 [==============================] - 0s 24ms/step
# H
# 1/1 [==============================] - 0s 21ms/step
# H
# 1/1 [==============================] - 0s 26ms/step
# H
# 1/1 [==============================] - 0s 23ms/step
# U
# 1/1 [==============================] - 0s 25ms/step
# U
# 1/1 [==============================] - 0s 25ms/step
# U
# 1/1 [==============================] - 0s 30ms/step
# U
# 1/1 [==============================] - 0s 27ms/step
# J
# 1/1 [==============================] - 0s 22ms/step
# J
# 1/1 [==============================] - 0s 28ms/step
# J
# 1/1 [==============================] - 0s 24ms/step
# J
# 1/1 [==============================] - 0s 38ms/step
# J
# J
# 1/1 [==============================] - 0s 20ms/step
# J
# 1/1 [==============================] - 0s 20ms/step
# J
# 1/1 [==============================] - 0s 21ms/step
# J
# 1/1 [==============================] - 0s 110ms/step
# J
# 1/1 [==============================] - 0s 108ms/step
# J
# 1/1 [==============================] - 0s 87ms/step
# J
# 1/1 [==============================] - 0s 108ms/step
# J
# 1/1 [==============================] - 0s 136ms/step
# J
# 1/1 [==============================] - 0s 103ms/step
# J
# 1/1 [==============================] - 0s 117ms/step
# J
# 1/1 [==============================] - 0s 22ms/step
# J
# 1/1 [==============================] - 0s 21ms/step
# J
# 1/1 [==============================] - 0s 23ms/step
# J
# 1/1 [==============================] - 0s 24ms/step
# J
# 1/1 [==============================] - 0s 26ms/step
# J
# 1/1 [==============================] - 0s 26ms/step
# J
# 1/1 [==============================] - 0s 29ms/step
# J
# 1/1 [==============================] - 0s 29ms/step
# J
# 1/1 [==============================] - 0s 37ms/step
# J
# 1/1 [==============================] - 0s 26ms/step
# J
# 1/1 [==============================] - 0s 25ms/step
# J
# 1/1 [==============================] - 0s 20ms/step
# J
# 1/1 [==============================] - 0s 20ms/step
# J
# 1/1 [==============================] - 0s 23ms/step
# J
# 1/1 [==============================] - 0s 27ms/step
# J
# 1/1 [==============================] - 0s 25ms/step
# J
# 1/1 [==============================] - 0s 29ms/step
# J
# 1/1 [==============================] - 0s 24ms/step
# C
# 1/1 [==============================] - 0s 20ms/step
# C
# 1/1 [==============================] - 0s 20ms/step
# C
# 1/1 [==============================] - 0s 25ms/step
# C
# 1/1 [==============================] - 0s 31ms/step
# C
# 1/1 [==============================] - 0s 25ms/step
# C
# 1/1 [==============================] - 0s 24ms/step
# C
# 1/1 [==============================] - 0s 28ms/step
# C
# 1/1 [==============================] - 0s 28ms/step
# C
# 1/1 [==============================] - 0s 26ms/step
# C
# 1/1 [==============================] - 0s 20ms/step
# C
# 1/1 [==============================] - 0s 23ms/step
# C
# 1/1 [==============================] - 0s 29ms/step
# C
# 1/1 [==============================] - 0s 31ms/step
# C
# 1/1 [==============================] - 0s 27ms/step
# C
# 1/1 [==============================] - 0s 19ms/step
# C
# 1/1 [==============================] - 0s 32ms/step
# C
# 1/1 [==============================] - 0s 22ms/step
# C
# 1/1 [==============================] - 0s 26ms/step
# C
# 1/1 [==============================] - 0s 27ms/step
# X
# 1/1 [==============================] - 0s 23ms/step
# J
# 1/1 [==============================] - 0s 24ms/step
# J
# 1/1 [==============================] - 0s 27ms/step
# C
# 1/1 [==============================] - 0s 25ms/step
# C
# 1/1 [==============================] - 0s 23ms/step
# C
# 1/1 [==============================] - 0s 24ms/step
# C
# 1/1 [==============================] - 0s 25ms/step
# C
# 1/1 [==============================] - 0s 26ms/step
# C
# 1/1 [==============================] - 0s 27ms/step
# C
# 1/1 [==============================] - 0s 36ms/step
# C
# 1/1 [==============================] - 0s 32ms/step
# C
# 1/1 [==============================] - 0s 29ms/step
# J
# 1/1 [==============================] - 0s 38ms/step
# J
# 1/1 [==============================] - 0s 24ms/step
# J
# 1/1 [==============================] - 0s 27ms/step
# J

# %%
cap.release()
cv2.destroyAllWindows()

# %%
cv2.rectangle??

# %%
cap.release()
cv2.destroyAllWindows()
